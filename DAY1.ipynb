# %%
print("Hello Programming")
print("Welcome to Python")
# Out:
# Hello Programming
# Welcome to Python

# %%
print("My Name is Manasa \n I am learning Python")
# Out:
# My Name is Manasa
#  I am learning Python

# %%
x=[10,20,30]
print(x)
# Out:
# [10, 20, 30]

# %%
x=5
y=3
print(x+5)
# Out:
# 10

# %%
print('She said "Python is easy"')
# Out:
# She said "Python is easy"

# %%
print('Name : Manasa \n Age : 22 \n city : Banglore')
# Out:
# Name : Manasa
#  Age : 22
#  city : Banglore

# %%
print("*")
print("**")
print("***")
print("****")
print("*****")
# Out:
# *
# **
# ***
# ****
# *****

# %%
print("python is fun")

# %%
x = 15
y = 25
sum = x + y
print(sum)
# Out:
# 40

# %% [markdown]
# VARIABELS

# %%
Name = "manasa"
age = 22
print('Name : "my name is manasa"')
print('age: "i am 22 years old"')
# Out:
# Name : "my name is manasa"
# age: "i am 22 years old"

# %%
a = 10
b = 20
x= a+b
print(x)
# Out:
# 30

# %%
##Store three numbers in variables and print their sum

a = 10
b = 20
c = 30
sum = a+b+c
print(sum)
# Out:
# 60

# %%
## create a variable and Calculate area of rectangle - formula = > area = length*width
length = 25
width = 6
area = length * width
print(area)
# Out:
# 150

# %%
## Swap two variables.
a = 6
b = 3
temp = a
a = b
b = temp
print("a :" , a)
print("b :" ,b)

## or

a = 6
b = 3

a, b = b, a

print(a)
print(b)
# Out:
# a : 3
# b : 6
# 3
# 6

# %%
## Calculate total cost => price * quantity = total cost

price = 100
quantity = 3
total_cost= price*quantity
print("total_cost:",total_cost)
# Out:
# total_cost: 300

# %%
##Create a variable name and print:Hello Manasa ,Welcome to Python

name = str("Hello Manasa \n Welcome to Python")
print(name)
# Out:
# Hello Manasa
#  Welcome to Python

# %%
## Store a number in a variable and print its square

a=2
square = a*a
print(square)
# Out:
# 4

# %% [markdown]
# DATA TYPES AND TYPE CASTING

# %%
## Print the data type of each variable

a = 10
b = 3.5
c = "Python"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
##Store a number in a variable and print:
x = 2
print(x)
type(x)
# Out:
# 2
# int

# %%
## Convert this string to integer:
num = "25"
x = int(num)

print(type(x))
# Out:
# <class 'int'>

# %%
## convert int to float
num = 10
a = float(num)
print(type(a))
# Out:
# <class 'float'>

# %%
##Take a number from user and convert it to integer
num = int(input("Enter any number"))
print(num)
print(type(num))
# Out:
# Enter any number23
# 23
# <class 'int'>

# %%
a = 10
b= 7
result = a<b
print(result)
# Out:
# False

# %%
## Convert this string number to integer and add 10
num = "50"
a = int(num)
b = 10
result = a+b
print(result)
# Out:
# 60

# %%
##Convert the integer 25 to: float ,string ,boolean

num  = 25
a = float(num)
b = str(num)
c = bool(num)
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Input / Output

# %%
## Take the user's name and print a welcome message
user_Name =str(input("Enter your Name :"))
print("welcome", user_Name)
# Out:
# Enter your Name :manasa
# welcome manasa

# %%
## sum of two numbers

num1 = int(input('Enter first number'))
num2=int(input('Enter Second number'))
sum = num1 + num2
print("sum",sum)
# Out:
# Enter first number2
# Enter Second number3
# sum 5

# %%
## multiply two numbers
a=int(input("enter first number"))
b=int(input("enter second number"))
product = a*b
print(product)
# Out:
# enter first number25
# enter second number2
# 50

# %%
## Simple intrest program
## SI = (P*R*T)/100

P=float(input("Enter principle amount:" ))
R=float(input("Enter rate of intrest: "))
T=float(input("Enter time: "))
SI=(P*T*R)/100
print(SI)
# Out:
# Enter principle amount:2087
# Enter rate of intrest: 34
# Enter time: 3
# 2128.74

# %%
## Square of a number

num = int(input("Enter a number"))
square = num * num
print("square",square)
# Out:
# Enter a number2
# square 4

# %%
## TEMEPERATURE CONVERTER

## F = (C × 9/5) + 32

c = float(input("Enter temperature in Celsius: "))

f = (c * 9/5) + 32

print("Temperature in Fahrenheit:", f)
# Out:
# Enter temperature in Celsius: 90
# Temperature in Fahrenheit: 194.0

# %%
## AREA OF RECTANGLE
## Area = length × breadth

length=float(input("Enter length: "))
breadth=float(input("Enter breadth:" ))
area = length * breadth
print("area", area)
# Out:
# Enter length: 34
# Enter breadth:12
# area 408.0

# %%
## swap two numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

temp = a
a = b
b = temp
print("After Swapping")
print("a =",a)
print("b =",b)
# Out:
# Enter first number: 2
# Enter second number: 3
# After Swapping
# a = 3
# b = 2

# %%
## USER PROFILE PROGRAM
name = str(input("Enter a name:"))
age = int(input("Enter a age"))
city = str(input("Enter a city"))
print("name",name)
print("city",city)
print("age", age)
# Out:
# Enter a name:Mansa
# Enter a age22
# Enter a cityBanglore
# name Mansa
# city Banglore
# age 22

# %%
## CUBE OF A NUMBER
num=int(input("Enter a number:"))
cube = num*num*num
print("cube",cube)
# Out:
# Enter a number:2
# cube 8

# %%
## take a number from user nd souble it

num=int(input("Enter a number"))
num = num *2
print(num)
# Out:
# Enter a number6
# 12

# %%
## calculator
num1 =int(input("Enter First number: "))
num2 = int(input("Enter Second NUmber: "))


addition = num1 + num2
subtraction = num1 - num2
division = num1 / num2
multiplication = num1 *num2
print("addition" , addition)
print("subtarction" , subtraction)
print("multiplication", multiplication)
print("division", division)
# Out:
# Enter First number: 2
# Enter Second NUmber: 3
# addition 5
# subtarction -1
# multiplication 6
# division 0.6666666666666666
