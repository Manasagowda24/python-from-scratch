# %% [markdown]
# LIST :-
# list is an orderd ,mutable collection of elements allows duplicate values

# %%
'''
Write a program to:

Take a list of numbers
 Create a new list that contains:

square of even numbers
cube of odd numbers
'''

num = [1,2,3,4,5,6]
result = []
for num in range(7):
  if num%2==0:
    result.append(num**2)
  else:
    result.append(num**3)
print(result)
# Out:
# [0, 1, 4, 27, 16, 125, 36]

# %%
## or list Comprehension

num = [1,2,3,4,5,6]
result = [num**2 if num%2==0 else num**3 for num in nums]
print(result)
# Out:
# [36, 343, 16, 729, 4]

# %%
'''Given a list:

num = [10, 20, 30, 40, 50]

Do the following:

Replace the first element with 100
Remove 30
Add 60 at the end
Print final list '''

num = [10, 20, 30, 40, 50]
num[0]=100
num.remove(30)
num.append(60)
print(num)
# Out:
# [100, 20, 40, 50, 60]

# %%
''' t = (10, 20, 30)
Unpack into 3 variables
Print their sum '''

t = (10, 20, 30)
a,b,c = t
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
'''
Create a list using list comprehension:

numbers from 1 to 20
include only numbers divisible by 3 '''


num = [i for i in range(1, 21) if i % 3 == 0]
print(num)
# Out:
# [3, 6, 9, 12, 15, 18]

# %%
'''t = (1, [2, 3, 4])
Change 3 → 100
Print updated tuple '''
t = (1, [2, 3, 4])
t[1][1] = 100
print(t)
# Out:
# (1, [2, 100, 4])
