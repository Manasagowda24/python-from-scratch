# %% [markdown]
# AIRTHMATIC OPERATION -
# Arithmetic operators are used to perform mathematical calculations in Python
#
# --
# addition ,
# subtraction,
# multiplication,
# division,
# power,
# remainder

# %%
## Write a program to take two numbers as input and print:addition,subtraction,multiplication,division

num1 = int(input("Enter First Number"))
num2 = int(input("Enter Second Number"))
addition = num1+num2
subtraction = num1-num2
multiplication = num1*num2
division = num1/num2
print("adiition :" , addition)
print("subtraction :",subtraction)
print("multiplication :", multiplication)
print("division :" , division)
# Out:
# Enter First Number4
# Enter Second Number5
# adiition : 9
# subtraction : -1
# multiplication : 20
# division : 0.8

# %%
##Write a program to find the remainder when one number is divided by another.
num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))
result = num1%num2
print(result)
# Out:
# Enter first number6
# Enter second number3
# 0

# %%
## Take a number and print its square and cube.
num = int(input("enter first number"))
square = num*num
cube = num*num*num
print(square)
print(cube)
# Out:
# enter first number4
# 16
# 64

# %%
## Write a program to calculate the area of a circle (use formula: π * r², take radius as input

radius = float(input("Enter a Number"))
pi = 3.14
area = pi * radius*radius
print("area :", area )
# Out:
# Enter a Number6
# area : 113.03999999999999

# %%
## Write a program to convert minutes into hours and remaining minutes.
minutes = int(input("Enter a minute"))
hours = minutes // 60
remaining_minutes = minutes%60
print(remaining_minutes)
print(hours)

## // -> gives quetiont
## % -> gives remainder
# Out:
# Enter a minute456
# 36
# 7

# %%
"""
Write code to print
The sum of a and b
The remainder when a is divided by b
The result of a raised to the power of b """


a = 15
b = 4
sum= a+b
remainder = a % b
power = a**b
print(sum)
print(remainder)
print(power)
# Out:
# 19
# 3
# 50625

# %%
"""
Q2. You bought 5 pens and each pen costs ₹12. Create variables for the quantity
and price, then print the total cost """

quantity = 5
price = 12
total_cost = price * quantity
print(total_cost)
# Out:
# 60

# %%
"""
3. You have num = 17.

Print the result of num divided by 5 (normal division)
Print how many times 5 fits into 17 fully (floor division)
Print the remainder when 17 is divided by 5 """

num = 17
division = num / 5
quotient = num // 5
remainder = num % 5
print(division)
print(quotient)
print(remainder)
# Out:
# 3.4
# 3
# 2

# %%
'''
You scored total_marks = 432 in 6 subjects.
Print your average marks per subject.'''

total_marks = 432
total_subject = 6
avg_marks = total_marks / total_subject
print(avg_marks)
# Out:
# 72.0

# %%
'''
 A shopkeeper has 150 apples. He wants to pack them into bags of 12 each.

Print how many full bags he can make
Print how many apples are left over
'''
total_apple = 150
num_of_bags = total_apple // 12
remainder = total_apple % 12

print(num_of_bags)
print(remainder)
# Out:
# 12
# 6

# %%
'''
 Take a number n = 5. Print n raised to the power of 3.
 Then print the result of n raised to the power of 3, divided by 2 (normal division) '''

n = 5
power= n**3
division = power/ 2
print(division)
# Out:
# 62.5

# %%
'''
Q8. You are saving money:

daily_savings = 35
days = 30
Print total savings for the month
Print how many full weeks are in those 30 days (use floor division!)
Print how many extra days are left after full weeks (use modulo!) '''

daily_savings = 35
days = 30
month_saving = daily_saving * 30
full_weak = days // 7
extra_days =

# %% [markdown]
# COMPARISION OPERATOR

# %%
num1 = int(input("enter first number "))
num2 = int(input("enter second number "))
result1 = num1 > num2
result2 = num1 < num2
result3 = num1 = num2
print(result1)
print(result2)
print(result3)
# Out:
# enter first number 5
# enter second number 6
# False
# True
# 6

# %%
'''
Take two numbers and print the result of
equality and inequality comparison.'''


num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))
result1 = num1 == num2
result2 = num1 != num2
print(result1)
print(result2)
# Out:
# Enter first number45
# Enter second number56
# False
# True NOT EQUAL

# %%
'''
Take two numbers and print the result
of greater than or equal to and less than or equal to '''

num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))
result1 = num1 >= num2
result2 = num1 <= num2
print(result1)
print(result2)
# Out:
# Enter first number56
# Enter second number78
# False
# True

# %%
num1 = int(input("Enter a number"))
a = num1 ==  0
b = num1 >=  0
c = num1 != 0
print(a)
print(b)
print(c)
# Out:
# Enter a number56
# False
# True
# True

# %% [markdown]
# LOGICAL OPERATOR

# %%
''' Take two numbers and print the result using
 logical AND with two comparison conditions.'''

num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))
a = num1>num2 and num1>=num2
b = num1!=num2 and num1<num2
print(b)
print(a)
# Out:
# Enter first number34
# Enter second number45
# True
# False

# %%
## OR
num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))
a = num1>num2 or num1>=num2
b = num1!=num2 or num1<num2
print(b)
print(a)
# Out:
# Enter first number45
# Enter second number67
# True
# False

# %%
'''Take a number and print the result
 using logical NOT with a comparison condition.'''

num = int(input("Enter a number"))
a = num > 9 #  if numis 10 then 10 > 9 = true  but not reverse it as false
b = not(a) # it reverse the condition
print(b)
# Out:
# Enter a number10
# False

# %%
'''Take three numbers and print the result using logical
AND between all conditions.'''


num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))
num3 = int(input("Enter  third number"))
result = num1>num2 and num2<num3 and num1!=num2
print(result)
# Out:
# Enter first number56
# Enter second number46
# Enter  third number57
# True

# %% [markdown]
# Assignment Operators

# %%
from re import X
'''Take a number and add 10 to it using an
assignment operator, then print the result'''

x = int(input("Enter a number"))
x+= 10
print(x)
# Out:
# Enter a number5
# 15

# %%
''' Take a number and subtract 5 from it using an assignment operator,
 then print the result '''

x = int(input("Enter a number"))
x-= 5
print(x)
# Out:
# Enter a number25
# 20

# %%
''' Take a number and multiply it by 3 using an assignment operator,
then print the result'''
x = int(input("Enter a number"))
x*= 3
print(x)
# Out:
# Enter a number3
# 9

# %%
''' Take a number and divide it by 2 using
 an assignment operator, then print the result.'''
x = int(input("Enter a number"))
x/= 3
print(x)
# Out:
# Enter a number6
# 2.0

# %%
'''Take a number and apply multiple assignment operators step by step
 (add, subtract, multiply), then print the final result.'''

x = int(input("Enter a number"))
x+= 3
x-= 6
x*= 8
x/= 3
print(x)
# Out:
# Enter a number50
# 125.33333333333333

# %% [markdown]
# MEMBERSHIP OPERAT

# %%
## Take a string and print whether a specific character is present in it.

text = "python"
print('p' in text)
print('o'in text)
# Out:
# True
# True

# %%
## Take a list of numbers and print whether a given number is in the list.

a = [1,2,3,4]
print(2 in a)
# Out:
# True

# %%
## Take a string and print whether a specific character is not present in it

text = "python"
print('p' not in text)
# Out:
# False

# %%
## Take a list and print whether an element is not in the list.

a = [1,2,3,4,5]
print(1 not in a)
# Out:
# False

# %%
## Take a word and check if a particular letter exists in it

a = "manasa"
print('ma' in a)
# Out:
# True

# %% [markdown]
# Identity Operators

# %%
## Take two variables with same value and print the result using identity operator.
a = 450
b = 450
print(a is b)
# Out:
# False

# %%
## Take two variables with different values and print the result using identity operator.
a = 25
b = 35
print(a is b)
# Out:
# False

# %%
## Assign one variable to another and check identity between them.
a = 10
b = a
print(a is b)
# Out:
# True

# %%
## Take two lists with same values and check identity
a = [1,2,3,4,5]
b = [1,2,3,4,5]
print(a is b)
print(a == b)
print(a is not b)
# Out:
# False
# True
# True

# %% [markdown]
# CONDITIONAL STATEMENT

# %%
## Take a number and print it only if it is greater than 10.
num = int(input("enter a number "))
if num > 10:
  print(num)
# Out:
# 15

# %%
## Take a number and print it only if it is divisible by 2.
num = int(input("enter a number"))
if num%2==0:
  print(num)
# Out:
# enter a number3

# %%
## Take a number and print it only if it is negative.
num = -1
if num < 0 :
  print('num : ', num ,"negative")
# Out:
# num :  -1 negative

# %%
## Take a number and print whether it is even or odd
num = int(input("enter a number "))
if num %2==0 :
  print("even number")
else:
  print("odd number")
# Out:
# enter a number 8
# 8  : even number

# %%
## Take a number and print whether it is positive or negative.
num = int(input("enter a number "))
if num >= 0 :
  print("number is positive")
else:
  print("number is neagtive")
# Out:
# enter a number 4
# number is positive

# %%
##  take a number and print whether it is divisible by 5 or not.
num = int(input("enter a number "))
if num /5:
  print("dividible by 5")
else:
  print("not divisible by 5")
# Out:
# enter a number 25
# dividible by 5

# %%
## Take two numbers and print which one is greater.
num1 = int(input("Enter a First number "))
num2 = int(input("Enter a Second numbe0r "))
if num1>num2 :
  print("num1 is greater")
else:
  print("num2 is greater")
# Out:
# Enter a First number34
# Enter a Second number23
# num1 is greater

# %%
## Take a number and print whether it is positive, negative, or zero
num = int(input("Enter a number "))
if num > 0:
  print("num is positive")
elif num == 0:
  print("num is zero")
else:
  print("num is negative")
# Out:
# Enter a number -65
# num is negative

# %%
## Take marks as input and print grade.
sub1 = float(input("enter sub1 marks "))
sub2 = float(input("enter sub2 marks "))
sub3 = float(input("enter sub3 marks "))
total_marks = 90
total_score = sub1+sub2+sub3
avg = total_score / total_marks * 100
if avg >= 90:
  print("Distinction -", f"{avg:.2f}" ,"Grade:'A'")
elif avg >=70 and avg<=89 :
  print("First class -" , f"{avg:.2f}" , "Grade:'B'")
elif avg >=50 and avg<=69:
  print("pass -", f"{avg:.2f}", " Grade:'c'")
else:
  print("Fail")
# Out:
# enter sub1 marks 23
# enter sub2 marks 22
# enter sub3 marks 23
# First class - 75.56 Grade:'B'

# %%
''' Take a number and print:
if it is divisible by 3
divisible by 5
divisible by both
or none '''

num = float(input("Enter a number "))
if num %3==0 and num %5==0 :
  print("number is divisible by both 3 and 5 ")
elif num %5==0 :
 print("number is divisible by 5 ")
elif num %3==0:
 print("number is divisible by 3")
else:
  print("none")
# Out:
# Enter a number 55
# number is divisible by 5

# %%
## Take age as input and print category (child, adult, senior).
age = int(input("Enter your age "))
if age >= 65:
  print("senior")
elif age <= 64 and age >= 18:
  print("adult")
else :
  print("child")
# Out:
# Enter your age 65
# senior

# %%
''' Take a number and check:
if it is positive
if positive, then check if it is even or odd '''

num = int(input("Enter a Number "))
if  num > 0:
  print("positive")
  if num %2==0:
    print("number is even")
  else:
    print("odd")
# Out:
# Enter a Number4
# positive
# number is even

# %%
''' Take a number and check:
if it is divisible by 2
if yes, then check if it is divisible by 4 '''

num = int(input("Enter a Number "))
if num %2 == 0:
  print("number divisible by 2")
  if num %4==0:
    print("number is divisible by 4")
# Out:
# Enter a Number 24
# number is divisible by 4

# %%
''' Take age and check:
if age ≥ 18
if yes, then check if age ≥ 60 '''

age = int(input("Enter  your age "))
if age >= 18:
  print("age is greater than 18")
if  age >= 60 :
  print("Age is greater than 60")
# Out:
# Enter  your age56
# age is greater than 18

# %%
''' Take a number and check:
if it is positive
if yes, check if it is divisible by 2
if yes, check if it is greater than 50 '''

num = int(input("Enter a Number "))
if num > 0:
  if num%2==0 :
    print("number is divisible by 2")
    if num > 50:
      print("number is greater than  50")
# Out:
# Enter a Number 250
# number is divisible by 2
# number is greater than  50

# %%
'''' Take three numbers and
check if all are positive
if yes, print the largest among them
if any number is negative, print "Invalid input" '''

num1 =int(input("enter  first number "))
num2 = int(input("enter second number "))
num3 = int(input("enter third number "))
if num1 < 0 or num2 < 0 or num3 < 0:
      print("invalid input")
else:
     if num1> num2 and num1> num3:
         print("num1 is greater ")
     elif num2 > num3:
        print("num2 is greater")
     else:
        print("num3 is greater")
# Out:
# enter  first number 3
# enter second number 7
# enter third number 11
# num3 is greater

# %%
'''
2.

Take marks of 3 subjects and each sub carry total marks as 30 so max marks = 90
if the user enter input more than 30 or less than 0 per sub thr0w as invalid:
thn
calculate percentage
if any subject < 35 → print "Fail"
else:
≥ 90 → Distinction
75–89 → First Class
50–74 → Second Class
else → Pass '''


sub1 = float(input("Enter sub1 marks "))
sub2 = float(input("ENter sub2 marks "))
sub3 = float(input("Enter sub3 marks "))
max_marks = 90
secured_marks = sub1+sub2+sub3
percentage =secured_marks / max_marks *100
if sub1>30 or sub2<0 and sub2>30 or sub2<0 and sub3>30 and sub3<0:
  print("invalid input")

elif sub1<35 or sub2<35 or sub3 <35:
       print("fail")
else:
  if percentage >= 90:
    print("Distinction")
  elif percentage >=75 :
    print("first class")
  elif percentage>= 50 :
    print("second class")
  else:
    print("pass")
# Out:
# Enter sub1 marks 45
# ENter sub2 marks 56
# Enter sub3 marks 66
# invalid input

# %%
'''Take a number and: if divisible by 2: check if divisible by 4 if yes, check if divisible by
8 else: check if divisible by 3
 if yes, check if greater than 50 '''

num = int(input("Enter a number "))

if num %2==0 :
  print("divisible by 2 ")
  if num %4==0 :
    print("divisible by 4 ")
    if num %8==0:
      print("divisible by 8")
else :
  if num %3==0:
    print("number divisible by 3 ")
    if num>50:
       print("num grtaer than 50 ")
# Out:
# Enter a number 12
# divisible by 2
# divisible by 4

# %%
'''Take username and password: if username is "admin": if password is "1234":
check if login attempts < 3 else: print "Wrong password"
 else: print "User not found" '''

## registration
reg_user = str(input("Enter your Name to register "))
reg_pass = int(input("enter your password to register "))

## login
print("please login ")
login_user = input("Enter username ")
login_pass = int(input("Enter password "))
attempts = int(input("enter login attempts "))
if login_user == reg_user:
    if login_pass == reg_pass:
        if attempts < 3:
            print("login successfull")
        else:
            print("too many attempts")
    else:
      print("wrong password")
else:
  print("user not found ")
# Out:
# Enter your Name to register manasa
# enter your password to register 1234
# please login
# Enter username manasa
# Enter password 1234
# enter login attempts 2
# login successfull

# %%
''' Take a number and: if number > 100: check if even if even,
check if divisible by 10 elif number between 50 and 100: check
if divisible by 5
 else: check if number is less than 0 '''

num = int(input("enter a number "))

if num > 100:
    if num % 2 == 0:
        print("number is even")
        if num % 10 == 0:
            print("number divisible by 10")

elif num>= 50 and num <= 100:
    print("num b/w 50 and 100")
    if num % 5 == 0:
        print("number divisible by 5")

else:
    if num < 0:
        print("number is less than 0")
# Out:
# enter a number 560
# number is even
# number divisible by 10

# %%
''' Take age and salary: if age ≥ 18: if salary ≥ 20000:
if salary ≥ 50000 → High tax else → Medium tax else →
Low income else: Not eligible '''

age = float(input("Enter a age :"))
salary = float(input("Enter a salary "))
if age>=18:
  if salary>=20000:
    if salary>=50000:
      print("high tax")
    else:
       print("medium tax")
  else:
    print("low income ")
else:
   print("not eligible")
# Out:
# Enter a age :57
# Enter a salary 670000
# high tax

# %%
''' Take two numbers and an operator (+, -, *, /):
if operator is + → perform addition if - →
subtraction if * → multiplication if /:
if second number is 0 → print error else perform division '''

num1 = int(input("enter first number "))
num2 = int(input("enter second number "))
operator = input("enter any operator ")
if operator == '+' :
  print("addition :" , num1 + num2)
elif operator == '-':
  print("subtraction :",num1 - num2)
elif operator =='*':
  print("multiplication:", num1*num2)
elif operator == '/':
  if num2 ==0:
    print("ZeroDivisionError")
else :
  print("division",num1/num2)
# Out:
# enter first number 4
# enter second number 0
# enter any operator /
# ZeroDivisionError

# %%
''' Take temperature: if temperature > 40:
check humidity > 70 → Very Hot else → Hot elif temperature between 20–40: check
 humidity > 50 → Warm else → Pleasant else: Cold '''

temp = float(input("Enter a temperature: "))
humidity= float(input("Enter  Humidity: "))
if temp>40:
  if humidity>70:
    print("very hot ")
  else:
    print("hot")
elif temp >=20 and temp >=40:
  print("temp b/w 20 and 40")
  if humidity > 50:
    print("warm")
  else:
    print("plesant")
else :
   print("cold")
# Out:
# Enter a temperature: 36
# Enter  Humidity: 4
# cold

# %%
''' Take a number: if positive: if even: if > 100 → Large Even else → Small Even else: if > 100 → Large Odd else → Small Odd else: print
"Negative number" '''

num = int(input("Enter a number: "))
if num > 0:
  if num %2==0:
    if num>100:
      print("large even")
    else :
      print("small even")
  elif num %2!= 0:
     if num >100:
      print("large odd")
     else:
      print("small odd")
else:
  print("Negative number")
# Out:
# Enter a number: 3
# small odd

# %%
''' Take total purchase amount: if amount ≥ 10000: if customer is premium:
if payment method is card → 20% discount else → 15% discount else: 10% discount elif amount ≥ 5000: 5% discount
 else: No discount '''
total_amount = float(input("Enter total purchase amount: "))
premium = bool(input("enter your premium status(Yes / No): "))
customer = premium
payment_method = input("enter your payment method (card/cash/UPI): ")

if total_amount >=10000:
  if customer == premium:
    print("customer is premium")
    if payment_method == "card"  :
       print("total_amount with discount of 20%" , 20 / total_amount * 100)
    elif payment_method != "card" :
           print("total_amount with discount of 15%" , 15 / total_amount * 100)
    else:
      print("total_amount with discount of 10%" , 10 / total_amount * 100)
elif total_amount >=5000:
  print("total_amount with discount of 10%" , 5 / total_amount * 100)
else:
   print("total_amount")
# Out:
# Enter total purchase amount: 6789
# enter your premium status(True or False): no
# enter your payment method (card/cash/UPI): cash
# total_amount with discount of 10% 0.07364854912358226
